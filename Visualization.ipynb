# %%
import pandas as pd

# %%
titanic=pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
import matplotlib.pyplot as plt

# %%
titanic.plot() # Obviously, when we call the plot() method, only the numerical values shall be plotted
plt.show()

# This data all together packed into 1 is actually not very helpful while plotting

# %% [markdown]
# #### So, lets separate the different variables

# %%
titanic.plot(subplots=True)
plt.show()

# %% [markdown]
# #### Lets make the figure a bit bigger

# %%
titanic.plot(subplots=True, figsize=(12,8)) # For the figsize, you have to determine the width and the height respectively
plt.show()

# %% [markdown]
# #### Can we have have the x-axis stated in each of the subplot?

# %%
titanic.plot(subplots=True, figsize=(14,12), sharex=False)
plt.show()

# %% [markdown]
# #### By default, the sharex is True and sharey is False.

# %% [markdown]
# #### Can we plot just 1 column instead of entire df?

# %%
titanic.age.plot(figsize=(12,8))
plt.show()

# %%
titanic.age.mean()
# Out:
# 29.69911764705882

# %% [markdown]
# #### Lets customize our plot a little bit:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# #### Can we make the fontsize in x and y axis a bit bigger?

# %%
titanic.age.plot(figsize=(12,10), fontsize=20)
plt.show()

# %% [markdown]
# #### Lets now change the color of the plot

# %%
titanic.age.plot(figsize=(12,10), fontsize=13, color="red") # Instead of color and red, you can also write c and "r"
plt.show()

# %% [markdown]
# #### What if we wanna change the linestyle?

# %%
titanic.age.plot(figsize=(12,10), fontsize=13, c="r", linestyle="--")
plt.show()

# %% [markdown]
# #### We have to look into the documentation to know what are the various kinds of colors and linestyles that the pandas provides. For now, lets back to the original line style:

# %%
titanic.age.plot(figsize=(12,10), fontsize=13, c="r", linestyle="-")
plt.show()

# %% [markdown]
# #### What about the title of the plot? How would I know what the plot is all about?

# %%
titanic.age.plot(figsize=(12,8), fontsize= 13, c="r", linestyle="-")
plt.title("Age of the people in titanic", fontsize=15)
plt.show()

# %% [markdown]
# #### There is one variable in the plot. But, if there were more than 1, can we add a legend in the plot that will help the readers navigate the plot?

# %%
titanic.age.plot(figsize=(12,8), fontsize=13, c="r", linestyle="-")
plt.title("Age of the people in titanic", fontsize=15)
plt.legend(loc=0, fontsize=15)

# %% [markdown]
# #### Have you noticed that we still do not know what the x-axis and y-axis actually represent?

# %%
titanic.age.plot(figsize=(12,8), fontsize=13, c="r", linestyle="-")
plt.title("Age of the people in titanic", fontsize=15)
plt.legend(loc=0, fontsize=15)
plt.xlabel("No. of Passengers", fontsize=13)
plt.ylabel("Age", fontsize=13)
plt.show()

# %% [markdown]
# #### To see the plot a bit more granularly, we can also introduce grids:

# %%
titanic.age.plot(figsize=(12,8), fontsize=13, c="r", linestyle="-")
plt.title("Age of the people in titanic", fontsize=15)
plt.legend(loc=0, fontsize=15)
plt.xlabel("No. of Passengers", fontsize=13)
plt.ylabel("Age", fontsize=13)
plt.grid()
plt.show()

# %% [markdown]
# #### What if we want to change x and yticks?

# %%
xtik=[x for x in range(0,901,50)]
ytik=[y for y in range(0,81,5)]

# %%
titanic.age.plot(figsize=(12,8), fontsize=13, c="r", linestyle="-", xticks=xtik, yticks=ytik)
plt.title("Age of the people in titanic", fontsize=15)
plt.legend(loc=0, fontsize=15)
plt.xlabel("No. of Passengers", fontsize=13)
plt.ylabel("Age", fontsize=13)
plt.grid()
plt.show()

# %% [markdown]
# #### There are actually many plot style that the matplotlib provides. Some of them are:

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use("seaborn")

# %%
titanic.age.plot(figsize=(12,8), fontsize=13, c="r", linestyle="-", xticks=xtik, yticks=ytik)
plt.title("Age of the people in titanic", fontsize=15)
plt.legend(loc=0, fontsize=15)
plt.xlabel("No. of Passengers", fontsize=13)
plt.ylabel("Age", fontsize=13)
#plt.grid() # Disabled coz in seaborn, the grid is by default true
plt.show()

# %% [markdown]
# #### how to create a histogram?

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
titanic=pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %% [markdown]
# #### Can we sort this age data into various bins?

# %%
titanic.age.value_counts(bins=10) # You can check whether its equal weight bins by subtracting the higher range by 
                                  # lower range. Here the difference is 7.958
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: age, dtype: int64

# %% [markdown]
# #### Now, lets potray this above bins in a plot namely, a histogram..!

# %%
titanic.age.plot(kind="hist", figsize=(8,12), fontsize=13)
plt.show()

# %% [markdown]
# #### You might have noticed that in the above code, we did not mention anything about bins. Nevertheless, the data was divided into 10 bins. This is because sorting into 10 bins is by default. However, we can easily change this.

# %%
titanic.age.plot(kind="hist", figsize=(12,8), fontsize=13, bins=80)
plt.show()

# %% [markdown]
# #### This histogram mentioned above can also be created in two other different ways. The first one is:

# %%
titanic.age.hist(figsize=(12,8), bins=80, xlabelsize=13, ylabelsize=13)
plt.show()

# %% [markdown]
# #### The 2nd way is:

# %%
plt.figure(figsize=(12,8))
plt.hist(titanic.age.dropna(), bins=80, density=False, cumulative=False)
plt.show()

# Note that this method cannot handle the missing values in the data. So, if your data has any na values, make sure to drop
# them.

# %% [markdown]
# #### So, as you can see, each method has some variations in it and serves different purposes.

# %% [markdown]
# ### Scatter plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
titanic=pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.plot(figsize=(12,8), kind="scatter", x="age", y="fare")
plt.show()

# %% [markdown]
# #### If I want to change the color, what should I do?

# %%
titanic.plot(kind="scatter", figsize=(12,8), x="age", y="fare", c="red")
plt.show()

# %% [markdown]
# #### Now, what if I wanted to have diamonds instead of dots OR any other way to visualize the data points?

# %%
titanic.plot(kind="scatter", figsize=(12,8), x="age", y="fare", c="red", marker="D")
plt.show()



# You can add many variations in the marker section such as "x", "X", "D", etc.

# You can also change the size of the dots by using s="20" or s="50" or whatever number suits you

# %% [markdown]
# #### How to convert this 2 dimensional plot into a 3 dimensional plot?

# %%
# Well if we simply add 1 more variable into the mix, then it might be possible

titanic.plot(kind="scatter", figsize=(12,8), x="age", y="fare", c="survived", marker="x")
plt.show()

# %% [markdown]
# #### But I cannot see anything in the plot. How can I even start interpreting the results? Make it a bit more readable

# %%
titanic.plot(kind="scatter", figsize=(12,8), x="age", y="fare", c="survived", marker="x", colormap="viridis")
plt.show()

# %% [markdown]
# #### In the above plot, we cannot see all the colors in action because the survived column has only two sets of datpoints i.e. 0 and 1.
#
# #### Lets try to put another datapoint and check the result

# %%
titanic.plot(kind="scatter", figsize=(12,8), x="age", y="fare", c="pclass", marker="x", colormap="viridis")
plt.show()

# Now you can see all the three colors in action

# %% [markdown]
# #### So from the plot above, a relationship can be observed:
#
# #### The young people tended to buy the 3rd class tickets and the older passengers tend to have 1st class tickets

# %% [markdown]
# ## Advanced /Statistical plotting with Seaborn

# %%
import seaborn as sns

# %% [markdown]
# #### Make a countplot using seaborn

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=titanic, x="sex")
plt.show()

# %% [markdown]
# #### If we pass the sex column to the y-axis, it will give out a horizontal countplot

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=titanic, y="sex")
plt.show()

# %% [markdown]
# #### Lets further sub-divide the male and female groups by passenger class

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=titanic, x="sex", hue="pclass")
plt.show()

# %% [markdown]
# #### Is there a way to customize this seaborn plot?
#
# #### Yes, by using the set () method, we can perform various operation. Feel free to check out the documentation

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=titanic, x="sex", hue="pclass")
sns.set(font_scale =2, palette="viridis") # There are various other options to choose from
plt.show()

# %% [markdown]
# ### Categorical plots with seaborn

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.stripplot(data=titanic, x="sex", y="age", hue="pclass")
plt.show()

# %% [markdown]
# #### In the above plot, althought the data of pclass has been plotted, due to the overalapping nature of the plot, we cannot infer anything meaningful. So, what do we do now?

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.stripplot(data=titanic, x="sex", y="age", hue="pclass", jitter=True)
plt.show()

# %% [markdown]
# #### Alright, this is certainly an improvement from before. But, still the datapoints for different classes among male and female are all mixed up. I wish there was a way to separate the pclasses within each sex

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.stripplot(data=titanic, x="sex", y="age", hue="pclass", jitter=True, dodge=True)
plt.show()

# %% [markdown]
# #### From the above figure, (for both sexes), it looks like that the 1st class passengers are older than the 2nd class and so on.

# %% [markdown]
# ## Swarmplot

# %% [markdown]
# #### Swarmplot: It is exactly like the stripplot except for the fact that we can actually the distribution of the data in each sub segment

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.swarmplot(data=titanic, x="sex", y="age", hue="pclass", dodge=True) # Also notice that there is parameter called jitter
plt.show()

# %% [markdown]
# #### We can infer from the above plot that in the male category, the 3rd class was mainly filled with 20-23 year old guys

# %% [markdown]
# ### Violin plot

# %% [markdown]
# #### Lets potray the same information as the previous plot but in a slightly different manner

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x="sex", y="age", hue="pclass", dodge=True) # The dodge reflects whether the datapoints are 
                                                                        # overlapping or not
plt.show()

# %% [markdown]
# #### Lets combine the swarm plot and the violin plot

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x="sex",y="age",hue="pclass", dodge=True)
sns.swarmplot(data=titanic, x="sex",y="age", hue="pclass", dodge=True, color="black")
plt.show()

# %% [markdown]
# #### Now, lets modify the x and y axis. For instance, Lets divide each pclass into male and female segments. The y-axis will have the age as usual

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x="pclass", y="age", hue="sex", dodge=True, split=True) #Split helps in assigning the 
                                                                        # distribution of male and female
                                                                        # on each side of the plot
plt.show()

# %% [markdown]
# #### The splitting helps us compare male vs female

# %% [markdown]
# ## Joint plots and Regression plots

# %%
sns.set(font_scale=1.5)
sns.jointplot(data=titanic, x="age", y="fare", kind="reg") # With "kind" parameter, you can select different kinds of joint
                                                        # plots. Similarly, you can use "height" para to determine the shape
                                                        # of the plot
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### There are also other methods to show the same regression plot

# %% [markdown]
# #### lmplot()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x="age", y="fare", aspect=1)
plt.show()

# %% [markdown]
# #### Imagine now, that you wanted to see which dot points resemble male and which points resemble female?

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x="age", y="fare", aspect=1, hue="sex")
plt.show()

# %% [markdown]
# #### Now it feels like all the info is conjusted. I can barely read anything in the plot. Is there a way to create a subplot?

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x="age", y="fare", aspect=1, col="sex")
plt.show()

# %% [markdown]
# #### When you have categorical variable in the model as a independent or dependent variable, make sure to use logistic regression

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x="age", y="survived", logistic=True)
plt.show()


# As the age increases, the chance of surviving in titanic decreases

# %% [markdown]
# #### Similarly, we can also examine a relationship between survived and sex

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x="age", y="survived", col="sex", logistic=True)
plt.show()

# %% [markdown]
# #### So the analysis says that for male, as you grow older, you have less chance of surviving
#
# #### Similarly for female, as they get old, their survival rate increases

# %% [markdown]
# #### Another way to skin the same cat is by separating the passengers by their classes and joining with survived passengers

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x="age", y="survived", aspect=1, logistic=True, col="pclass")
plt.show()

# %% [markdown]
# #### As can be clearly seen, in pclass 1, there are lots of surviving members in the early age category. This trend gradually reduces as we go from 1 to 3.

# %% [markdown]
# ## Matrix plots / Heatmaps

# %% [markdown]
# #### Prepare a cross tab and plot it. Take the values of sex and pclass

# %%
pd.crosstab(titanic.sex, titanic.pclass)
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.heatmap(pd.crosstab(titanic.sex, titanic.pclass), annot=True, fmt="d", cmap="Reds", vmax=150)
plt.show()

# %% [markdown]
# #### Now, lets do the same analysis using the survival rate

# %%
pd.crosstab(titanic.sex, titanic.pclass, values=titanic.survived, aggfunc="mean")
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.heatmap(pd.crosstab(titanic.sex, titanic.pclass, values=titanic.survived, aggfunc="mean"), annot=True, cmap="Reds")
plt.show()

# %% [markdown]
# #### Lets create a correlation matrix for all the columns in the titanic df

# %%
titanic.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.heatmap(data=titanic.corr(), annot=True, cmap="YlGnBu")
plt.show()
